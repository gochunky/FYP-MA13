# %%
# %pip install opencv-python
# %pip install matplotlib

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
import os
import cv2
import math
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
import seaborn as sns
from keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc

# %%
epochs = 8
batch_size = 16
img_size = 224

# %% [raw]
# preprocessing
# ├── train_data
# │   └── female
# │   └── male
# └── val_data
#     └── female
#     └── male

# %%
labels = ['female', 'male']

def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %% [markdown]
# # Without Pertubations

# %%
train = get_data('preprocessing/train_data')
val = get_data('preprocessing/val_data')
# Out:
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
model = Sequential()

model.add(Conv2D(32, 3, 3, padding="same", activation="relu", input_shape=(224,224,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()
#-----------------------------------------------------------------
opt = Adam(lr=0.000001)
model.compile(optimizer = opt , 
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics = ['accuracy'])
#------------------------------------------------------------------
# early_stop = EarlyStopping(monitor='loss', min_delta=0.001, patience=3, mode='min', verbose=1)
checkpoint = ModelCheckpoint('model_best_weights.h5', monitor='loss', verbose=1, # Saves checkpoints
                             save_best_only=True, mode='min', save_freq='epoch')

history = model.fit(x_train,y_train,epochs = epochs , 
                    validation_data = (x_val, y_val), 
                    callbacks = [checkpoint])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 75, 75, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 157,986
# Trainable params: 157,986
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.4701
# Epoch 00001: loss improved from inf to 0.69762, saving model to model_best_weights.h5
# 19/19 [==============================] - 3s 144ms/step - loss: 0.6976 - accuracy: 0.4701 - val_loss: 0.6928 - val_accuracy: 0.5017
# Epoch 2/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.4850
# Epoch 00002: loss improved from 0.69762 to 0.69494, saving model to model_best_weights.h5
# 19/19 [==============================] - 2s 107ms/step - loss: 0.6949 - accuracy: 0.4850 - val_loss: 0.6928 - val_accuracy: 0.5034
# Epoch 3/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6959 - accuracy: 0.5017
# Epoch 00003: loss did not improve from 0.69494
# 19/19 [==============================] - 2s 119ms/step - loss: 0.6959 - accuracy: 0.5017 - val_loss: 0.6928 - val_accuracy: 0.5069
# Epoch 4/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6966 - accuracy: 0.4767
# Epoch 00004: loss did not improve from 0.69494
# 19/19 [==============================] - 2s 111ms/step - loss: 0.6966 - accuracy: 0.4767 - val_loss: 0.6928 - val_accuracy: 0.5069
# Epoch 5/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5150
# Epoch 00005: loss improved from 0.69494 to 0.69303, saving model to model_best_weights.h5
# 19/19 [==============================] - 2s 119ms/step - loss: 0.6930 - accuracy: 0.5150 - val_loss: 0.6928 - val_accuracy: 0.5069
# Epoch 6/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6966 - accuracy: 0.5083
# Epoch 00006: loss did not improve from 0.69303
# 19/19 [==============================] - 2s 120ms/step - loss: 0.6966 - accuracy: 0.5083 - val_loss: 0.6928 - val_accuracy: 0.5069
# Epoch 7/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4983
# Epoch 00007: loss did not improve from 0.69303
# 19/19 [==============================] - 2s 108ms/step - loss: 0.6940 - accuracy: 0.4983 - val_loss: 0.6927 - val_accuracy: 0.5069
# Epoch 8/8
# 19/19 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.4867
# Epoch 00008: loss did not improve from 0.69303
# 19/19 [==============================] - 2s 120ms/step - loss: 0.6965 - accuracy: 0.4867 - val_loss: 0.6927 - val_accuracy: 0.5052

# %% [markdown]
# # With Pertubations

# %%
train_pert = get_data('preprocessing/makeup')
# Out:
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train_pert:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
model_pert = Sequential()

model_pert.add(Conv2D(32, 3, 3, padding="same", activation="relu", input_shape=(224,224,3)))
model_pert.add(MaxPool2D())

model_pert.add(Conv2D(32, 3, 3, padding="same", activation="relu"))
model_pert.add(MaxPool2D())
model_pert.add(Dropout(0.4))

model_pert.add(Flatten())
model_pert.add(Dense(128,activation="relu"))
model_pert.add(Dense(2, activation="softmax"))

model_pert.summary()
#-----------------------------------------------------------------
opt = Adam(lr=0.000001)
model_pert.compile(optimizer = opt , 
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics = ['accuracy'])
#------------------------------------------------------------------
# early_stop = EarlyStopping(monitor='loss', min_delta=0.001, patience=3, mode='min', verbose=1)
checkpoint = ModelCheckpoint('model_best_weights_pert.h5', monitor='loss', verbose=1, # Saves checkpoints
                             save_best_only=True, mode='min', save_freq='epoch')

history_pert = model_pert.fit(x_train,y_train,epochs = epochs , 
                    validation_data = (x_val, y_val), 
                    callbacks = [checkpoint])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 75, 75, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 157,986
# Trainable params: 157,986
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
# 14/14 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.4477
# Epoch 00001: loss improved from inf to 0.70173, saving model to model_best_weights_pert.h5
# 14/14 [==============================] - 2s 174ms/step - loss: 0.7017 - accuracy: 0.4477 - val_loss: 0.6955 - val_accuracy: 0.4828
# Epoch 2/8
# 14/14 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.5045
# Epoch 00002: loss improved from 0.70173 to 0.69599, saving model to model_best_weights_pert.h5
# 14/14 [==============================] - 2s 119ms/step - loss: 0.6960 - accuracy: 0.5045 - val_loss: 0.6954 - val_accuracy: 0.4794
# Epoch 3/8
# 14/14 [==============================] - ETA: 0s - loss: 0.6946 - accuracy: 0.5091
# Epoch 00003: loss improved from 0.69599 to 0.69460, saving model to model_best_weights_pert.h5
# 14/14 [==============================] - 2s 124ms/step - loss: 0.6946 - accuracy: 0.5091 - val_loss: 0.6953 - val_accuracy: 0.4794
# Epoch 4/8
# 14/14 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.4909
# Epoch 00004: loss did not improve from 0.69460
# 14/14 [==============================] - 2s 115ms/step - loss: 0.6957 - accuracy: 0.4909 - val_loss: 0.6952 - val_accuracy: 0.4794
# Epoch 5/8
# 14/14 [==============================] - ETA: 0s - loss: 0.6905 - accuracy: 0.5318
# Epoch 00005: loss improved from 0.69460 to 0.69046, saving model to model_best_weights_pert.h5
# 14/14 [==============================] - 2s 130ms/step - loss: 0.6905 - accuracy: 0.5318 - val_loss: 0.6951 - val_accuracy: 0.4880
# Epoch 6/8
# 14/14 [==============================] - ETA: 0s - loss: 0.7044 - accuracy: 0.4341
# Epoch 00006: loss did not improve from 0.69046
# 14/14 [==============================] - 2s 118ms/step - loss: 0.7044 - accuracy: 0.4341 - val_loss: 0.6950 - val_accuracy: 0.4914
# Epoch 7/8
# 14/14 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5023
# Epoch 00007: loss did not improve from 0.69046
# 14/14 [==============================] - 2s 130ms/step - loss: 0.6934 - accuracy: 0.5023 - val_loss: 0.6949 - val_accuracy: 0.5017
# Epoch 8/8
# 14/14 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.4909
# Epoch 00008: loss did not improve from 0.69046
# 14/14 [==============================] - 2s 119ms/step - loss: 0.6960 - accuracy: 0.4909 - val_loss: 0.6949 - val_accuracy: 0.5034

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Without Pertubation

# %% [markdown]
# ### Accuracy and Loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
num_of_train_samples = 602
num_of_test_samples = 582

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
validation_generator = test_datagen.flow_from_directory("preprocessing/val_data",
                                                        target_size=(224, 224),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
# Out:
# Found 587 images belonging to 2 classes.

# %%
Y_pred = model.predict_generator(validation_generator, num_of_test_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
confusion_matrix_array = confusion_matrix(validation_generator.classes, y_pred)
print(confusion_matrix_array)
df_cm = pd.DataFrame(confusion_matrix_array, range(2), range(2))
# plt.figure(figsize=(10,7))
sns.set(font_scale=1.4) # for label size
sns.heatmap(df_cm, annot=True, annot_kws={"size": 12}) # font size
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-15-f1e6193bdbd4>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Confusion Matrix
# [[258  47]
#  [251  31]]

# %% [markdown]
# ### Classification Report

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]

target_names = ['Female (Class 0)','Male (Class 1)']
print(classification_report(validation_generator.classes, y_pred, target_names=target_names, zero_division=1))
# Out:
# WARNING:tensorflow:From <ipython-input-16-bfb9a1e86c54>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#                   precision    recall  f1-score   support
#
# Female (Class 0)       0.51      0.85      0.63       305
#   Male (Class 1)       0.40      0.11      0.17       282
#
#         accuracy                           0.49       587
#        macro avg       0.45      0.48      0.40       587
#     weighted avg       0.45      0.49      0.41       587

# %% [markdown]
# ## With Pertubation

# %% [markdown]
# ### Accuracy and Loss

# %%
acc = history_pert.history['accuracy']
val_acc = history_pert.history['val_accuracy']
loss = history_pert.history['loss']
val_loss = history_pert.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
num_of_train_samples = 602
num_of_test_samples = 582

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
validation_generator = test_datagen.flow_from_directory("preprocessing/val_data",
                                                        target_size=(224, 224),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
# Out:
# Found 587 images belonging to 2 classes.

# %%
Y_pred = model_pert.predict_generator(validation_generator, num_of_test_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
confusion_matrix_array = confusion_matrix(validation_generator.classes, y_pred)
print(confusion_matrix_array)
df_cm = pd.DataFrame(confusion_matrix_array, range(2), range(2))
# plt.figure(figsize=(10,7))
sns.set(font_scale=1.4) # for label size
sns.heatmap(df_cm, annot=True, annot_kws={"size": 12}) # font size
plt.show()
# Out:
# Confusion Matrix
# [[173 132]
#  [164 118]]

# %% [markdown]
# ### Classification Report

# %%
predictions = model_pert.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]

target_names = ['Female (Class 0)','Male (Class 1)']
print(classification_report(validation_generator.classes, y_pred, target_names=target_names, zero_division=1))
# Out:
#                   precision    recall  f1-score   support
#
# Female (Class 0)       0.51      0.57      0.54       305
#   Male (Class 1)       0.47      0.42      0.44       282
#
#         accuracy                           0.50       587
#        macro avg       0.49      0.49      0.49       587
#     weighted avg       0.49      0.50      0.49       587

# %% [markdown]
# # Making predictions

# %% [markdown]
# ## Without Pertubation

# %%
def predictImage(filename):
    img = tf.keras.preprocessing.image.load_img(filename, target_size=(224, 224))
    input_arr = tf.keras.preprocessing.image.img_to_array(img)
    input_arr = np.array([input_arr])  # Convert single image to a batch.
    input_arr = input_arr.astype('float32') / 255.  # This is VERY important
    predictions = model.predict(input_arr)
    val = np.argmax(predictions, axis=-1)
    
    img1 = image.load_img(filename,target_size=(img_size,img_size))
    plt.imshow(img1)
    if val == 1:
        plt.xlabel("MALE",fontsize=30)
    elif val == 0:
        plt.xlabel("FEMALE",fontsize=30)

# %%
predictImage("trump.jpeg")

# %%
predictImage("gal.jpeg")

# %%
predictImage("clairo.jpeg")

# %% [markdown]
# ## With Pertubation

# %%
def predictImagePert(filename):
    img = tf.keras.preprocessing.image.load_img(filename, target_size=(224, 224))
    input_arr = tf.keras.preprocessing.image.img_to_array(img)
    input_arr = np.array([input_arr])  # Convert single image to a batch.
    input_arr = input_arr.astype('float32') / 255.  # This is VERY important
    predictions = model_pert.predict(input_arr)
    val = np.argmax(predictions, axis=-1)
    
    img1 = image.load_img(filename,target_size=(img_size,img_size))
    plt.imshow(img1)
    if val == 1:
        plt.xlabel("MALE",fontsize=30)
    elif val == 0:
        plt.xlabel("FEMALE",fontsize=30)

# %%
predictImagePert("trump.jpeg")

# %%
predictImagePert("gal.jpeg")

# %%
predictImagePert("clairo.jpeg")
