# %% [markdown]
# # Without Pertubations

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory("preprocessing/train_data",
                                          target_size=(image_size,image_size),
                                          batch_size = batch_size,
                                          class_mode = 'binary')
                                         
test_dataset = test.flow_from_directory("preprocessing/val_data",
                                      target_size=(image_size,image_size),
                                      batch_size = batch_size,
                                      class_mode = 'binary')
# Out:
# Found 602 images belonging to 2 classes.
# Found 587 images belonging to 2 classes.

# %%
test_dataset.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Convolution2D(32, 3, 3, input_shape = (image_size, image_size, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Convolution2D(32, 3, 3, activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(128, activation = 'relu'))
classifier.add(Dense(1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
#------------------------------------------------------------
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   rotation_range=15,
                                   vertical_flip=True,
                                   fill_mode='reflect',
                                   data_format='channels_last',
                                   brightness_range=[0.5, 1.5],
                                   featurewise_center=True,
                                   featurewise_std_normalization=True)

test_datagen = ImageDataGenerator(rescale = 1./255)
#------------------------------------------------------------
early_stop = EarlyStopping(monitor='loss', min_delta=0.001, patience=3, mode='min', verbose=1)
checkpoint = ModelCheckpoint('model_best_weights.h5', monitor='loss', verbose=1, # Saves checkpoints
                             save_best_only=True, mode='min', period=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = classifier.fit_generator(train_dataset,
         steps_per_epoch = 12,
         epochs = epochs,
         validation_data = test_dataset,
         callbacks = [early_stop,checkpoint]
         )
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/4
# 12/12 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5547
# Epoch 00001: loss improved from inf to 0.69022, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 198ms/step - loss: 0.6902 - accuracy: 0.5547 - val_loss: 0.6925 - val_accuracy: 0.5196
# Epoch 2/4
# 12/12 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.5291
# Epoch 00002: loss improved from 0.69022 to 0.68973, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 205ms/step - loss: 0.6897 - accuracy: 0.5291 - val_loss: 0.6820 - val_accuracy: 0.5911
# Epoch 3/4
# 12/12 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.5833
# Epoch 00003: loss improved from 0.68973 to 0.68161, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 200ms/step - loss: 0.6816 - accuracy: 0.5833 - val_loss: 0.6767 - val_accuracy: 0.6048
# Epoch 4/4
# 12/12 [==============================] - ETA: 0s - loss: 0.6742 - accuracy: 0.5661
# Epoch 00004: loss improved from 0.68161 to 0.67422, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 195ms/step - loss: 0.6742 - accuracy: 0.5661 - val_loss: 0.6876 - val_accuracy: 0.5486

# %%
average_no_pert = sum(history.history['val_accuracy'])/epochs
print("Average Validation Accuracy Without Pertubations: ", average_no_pert)
# Out:
# Average Validation Accuracy Without Pertubations:  0.6069846677780152

# %% [markdown]
# # With Pertubations

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory("preprocessing/makeup",
                                          target_size=(image_size,image_size),
                                          batch_size = batch_size,
                                          class_mode = 'binary')
                                         
test_dataset = test.flow_from_directory("preprocessing/val_data",
                                      target_size=(image_size,image_size),
                                      batch_size = batch_size,
                                      class_mode = 'binary')
# Out:
# Found 445 images belonging to 2 classes.
# Found 587 images belonging to 2 classes.

# %%
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Convolution2D(32, 3, 3, input_shape = (image_size, image_size, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Convolution2D(32, 3, 3, activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(128, activation = 'relu'))
classifier.add(Dense(1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
#------------------------------------------------------------
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   rotation_range=15,
                                   vertical_flip=True,
                                   fill_mode='reflect',
                                   data_format='channels_last',
                                   brightness_range=[0.5, 1.5],
                                   featurewise_center=True,
                                   featurewise_std_normalization=True)

test_datagen = ImageDataGenerator(rescale = 1./255)
#------------------------------------------------------------
early_stop = EarlyStopping(monitor='loss', min_delta=0.001, patience=3, mode='min', verbose=1)
checkpoint = ModelCheckpoint('model_best_weights.h5', monitor='loss', verbose=1, # Saves checkpoints
                             save_best_only=True, mode='min', period=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = classifier.fit_generator(train_dataset,
         steps_per_epoch = 12,
         epochs = epochs,
         validation_data = test_dataset,
         callbacks = [early_stop,checkpoint]
         )
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.5354
# Epoch 00001: loss improved from inf to 0.69416, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 189ms/step - loss: 0.6942 - accuracy: 0.5354 - val_loss: 0.6944 - val_accuracy: 0.5060
# Epoch 2/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6884 - accuracy: 0.5223
# Epoch 00002: loss improved from 0.69416 to 0.68843, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 171ms/step - loss: 0.6884 - accuracy: 0.5223 - val_loss: 0.6874 - val_accuracy: 0.5383
# Epoch 3/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.6115
# Epoch 00003: loss improved from 0.68843 to 0.66797, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 185ms/step - loss: 0.6680 - accuracy: 0.6115 - val_loss: 0.6906 - val_accuracy: 0.5400
# Epoch 4/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.6562
# Epoch 00004: loss improved from 0.66797 to 0.64571, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 187ms/step - loss: 0.6457 - accuracy: 0.6562 - val_loss: 0.6831 - val_accuracy: 0.5860
# Epoch 5/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.6168
# Epoch 00005: loss did not improve from 0.64571
# 12/12 [==============================] - 2s 176ms/step - loss: 0.6526 - accuracy: 0.6168 - val_loss: 0.6767 - val_accuracy: 0.5894
# Epoch 6/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.6509
# Epoch 00006: loss improved from 0.64571 to 0.63148, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 184ms/step - loss: 0.6315 - accuracy: 0.6509 - val_loss: 0.6852 - val_accuracy: 0.5707
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.6153 - accuracy: 0.6719
# Epoch 00007: loss improved from 0.63148 to 0.61525, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 175ms/step - loss: 0.6153 - accuracy: 0.6719 - val_loss: 0.6867 - val_accuracy: 0.5775
# Epoch 8/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.7161
# Epoch 00008: loss improved from 0.61525 to 0.58333, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 184ms/step - loss: 0.5833 - accuracy: 0.7161 - val_loss: 0.6864 - val_accuracy: 0.5860
# Epoch 9/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.7480
# Epoch 00009: loss improved from 0.58333 to 0.54211, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 184ms/step - loss: 0.5421 - accuracy: 0.7480 - val_loss: 0.6927 - val_accuracy: 0.5945
# Epoch 10/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5275 - accuracy: 0.7349
# Epoch 00010: loss improved from 0.54211 to 0.52754, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 179ms/step - loss: 0.5275 - accuracy: 0.7349 - val_loss: 0.7052 - val_accuracy: 0.5963
# Epoch 11/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4827 - accuracy: 0.7953
# Epoch 00011: loss improved from 0.52754 to 0.48266, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 187ms/step - loss: 0.4827 - accuracy: 0.7953 - val_loss: 0.7076 - val_accuracy: 0.5963
# Epoch 12/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.7953
# Epoch 00012: loss improved from 0.48266 to 0.46000, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 181ms/step - loss: 0.4600 - accuracy: 0.7953 - val_loss: 0.7043 - val_accuracy: 0.6116
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.8110
# Epoch 00013: loss improved from 0.46000 to 0.43182, saving model to model_best_weights.h5
# 12/12 [==============================] - 3s 257ms/step - loss: 0.4318 - accuracy: 0.8110 - val_loss: 0.7398 - val_accuracy: 0.6014
# Epoch 14/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.8294
# Epoch 00014: loss improved from 0.43182 to 0.39625, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 197ms/step - loss: 0.3963 - accuracy: 0.8294 - val_loss: 0.7794 - val_accuracy: 0.5945
# Epoch 15/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4004 - accuracy: 0.8399
# Epoch 00015: loss did not improve from 0.39625
# 12/12 [==============================] - 2s 187ms/step - loss: 0.4004 - accuracy: 0.8399 - val_loss: 0.7273 - val_accuracy: 0.6082
# Epoch 16/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8411
# Epoch 00016: loss improved from 0.39625 to 0.35506, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 186ms/step - loss: 0.3551 - accuracy: 0.8411 - val_loss: 0.7554 - val_accuracy: 0.6048
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3095 - accuracy: 0.8740
# Epoch 00017: loss improved from 0.35506 to 0.30951, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 180ms/step - loss: 0.3095 - accuracy: 0.8740 - val_loss: 0.7520 - val_accuracy: 0.6269
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.8714
# Epoch 00018: loss did not improve from 0.30951
# 12/12 [==============================] - 2s 173ms/step - loss: 0.3169 - accuracy: 0.8714 - val_loss: 0.7720 - val_accuracy: 0.6371
# Epoch 19/50
# 12/12 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8672
# Epoch 00019: loss did not improve from 0.30951
# 12/12 [==============================] - 2s 184ms/step - loss: 0.3273 - accuracy: 0.8672 - val_loss: 0.7981 - val_accuracy: 0.6014
# Epoch 20/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.9003
# Epoch 00020: loss improved from 0.30951 to 0.27097, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 183ms/step - loss: 0.2710 - accuracy: 0.9003 - val_loss: 0.8034 - val_accuracy: 0.6320
# Epoch 21/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.9003
# Epoch 00021: loss improved from 0.27097 to 0.26072, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 177ms/step - loss: 0.2607 - accuracy: 0.9003 - val_loss: 0.8510 - val_accuracy: 0.6184
# Epoch 22/50
# 12/12 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9265
# Epoch 00022: loss improved from 0.26072 to 0.22242, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 186ms/step - loss: 0.2224 - accuracy: 0.9265 - val_loss: 0.8672 - val_accuracy: 0.6269
# Epoch 23/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9423
# Epoch 00023: loss improved from 0.22242 to 0.17289, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 183ms/step - loss: 0.1729 - accuracy: 0.9423 - val_loss: 0.9001 - val_accuracy: 0.6252
# Epoch 24/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9528
# Epoch 00024: loss improved from 0.17289 to 0.14381, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 192ms/step - loss: 0.1438 - accuracy: 0.9528 - val_loss: 0.9816 - val_accuracy: 0.6235
# Epoch 25/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 0.9449
# Epoch 00025: loss did not improve from 0.14381
# 12/12 [==============================] - 2s 179ms/step - loss: 0.1515 - accuracy: 0.9449 - val_loss: 0.9182 - val_accuracy: 0.6422
# Epoch 26/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9790
# Epoch 00026: loss improved from 0.14381 to 0.11318, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 187ms/step - loss: 0.1132 - accuracy: 0.9790 - val_loss: 1.1251 - val_accuracy: 0.6150
# Epoch 27/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9531
# Epoch 00027: loss did not improve from 0.11318
# 12/12 [==============================] - 2s 181ms/step - loss: 0.1411 - accuracy: 0.9531 - val_loss: 0.9643 - val_accuracy: 0.6320
# Epoch 28/50
# 12/12 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9685
# Epoch 00028: loss improved from 0.11318 to 0.11317, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 178ms/step - loss: 0.1132 - accuracy: 0.9685 - val_loss: 1.0164 - val_accuracy: 0.6167
# Epoch 29/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9764
# Epoch 00029: loss improved from 0.11317 to 0.09454, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 191ms/step - loss: 0.0945 - accuracy: 0.9764 - val_loss: 1.1071 - val_accuracy: 0.6201
# Epoch 30/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9816
# Epoch 00030: loss improved from 0.09454 to 0.08503, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 178ms/step - loss: 0.0850 - accuracy: 0.9816 - val_loss: 1.1444 - val_accuracy: 0.6337
# Epoch 31/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9818
# Epoch 00031: loss did not improve from 0.08503
# 12/12 [==============================] - 2s 176ms/step - loss: 0.0863 - accuracy: 0.9818 - val_loss: 1.3006 - val_accuracy: 0.6235
# Epoch 32/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9921
# Epoch 00032: loss improved from 0.08503 to 0.06725, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 182ms/step - loss: 0.0673 - accuracy: 0.9921 - val_loss: 1.2533 - val_accuracy: 0.6201
# Epoch 33/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9974
# Epoch 00033: loss improved from 0.06725 to 0.04529, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 179ms/step - loss: 0.0453 - accuracy: 0.9974 - val_loss: 1.2768 - val_accuracy: 0.6303
# Epoch 34/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 00034: loss improved from 0.04529 to 0.04201, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 1.3147 - val_accuracy: 0.6388
# Epoch 35/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9974
# Epoch 00035: loss improved from 0.04201 to 0.03694, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 175ms/step - loss: 0.0369 - accuracy: 0.9974 - val_loss: 1.3530 - val_accuracy: 0.6354
# Epoch 36/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9974
# Epoch 00036: loss improved from 0.03694 to 0.02930, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 181ms/step - loss: 0.0293 - accuracy: 0.9974 - val_loss: 1.3522 - val_accuracy: 0.6474
# Epoch 37/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 1.0000
# Epoch 00037: loss improved from 0.02930 to 0.02090, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 187ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 1.4438 - val_accuracy: 0.6388
# Epoch 38/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 1.0000
# Epoch 00038: loss improved from 0.02090 to 0.01700, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 193ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 1.4997 - val_accuracy: 0.6286
# Epoch 39/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 00039: loss improved from 0.01700 to 0.01424, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 188ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 1.5648 - val_accuracy: 0.6303
# Epoch 40/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 1.0000
# Epoch 00040: loss did not improve from 0.01424
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 1.5034 - val_accuracy: 0.6371
# Epoch 41/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 00041: loss improved from 0.01424 to 0.01225, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 1.5398 - val_accuracy: 0.6371
# Epoch 42/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 00042: loss improved from 0.01225 to 0.01102, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 188ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.5834 - val_accuracy: 0.6320
# Epoch 43/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00043: loss improved from 0.01102 to 0.00916, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 182ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.6271 - val_accuracy: 0.6286
# Epoch 44/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 00044: loss improved from 0.00916 to 0.00839, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 185ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.6783 - val_accuracy: 0.6184
# Epoch 45/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00045: loss improved from 0.00839 to 0.00714, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 182ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.6876 - val_accuracy: 0.6354
# Epoch 46/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00046: loss improved from 0.00714 to 0.00676, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 189ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.7070 - val_accuracy: 0.6286
# Epoch 47/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00047: loss improved from 0.00676 to 0.00555, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.6855 - val_accuracy: 0.6320
# Epoch 48/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00048: loss improved from 0.00555 to 0.00538, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 184ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7372 - val_accuracy: 0.6320
# Epoch 49/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00049: loss did not improve from 0.00538
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7522 - val_accuracy: 0.6269
# Epoch 50/50
# 12/12 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00050: loss improved from 0.00538 to 0.00481, saving model to model_best_weights.h5
# 12/12 [==============================] - 2s 180ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7521 - val_accuracy: 0.6337
# Epoch 00050: early stopping
